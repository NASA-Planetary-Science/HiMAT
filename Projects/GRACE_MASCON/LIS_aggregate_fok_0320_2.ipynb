# %% [markdown]
# ### Code to aggregate NASA LIS data to GRACE mascons

# %% [markdown]
# ### Load the packages

# %%
# Jupter notebook magic
# %matplotlib inline

# Import libraries to work with the data
import os
import sys
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy import signal
import scipy.optimize
from scipy import stats
import geopandas as gpd
import pandas as pd
import s3fs
import salem
from PyAstronomy import pyasl
import xarray as xr
from datetime import datetime, timedelta
import boto3
import botocore
import dask.array as da
import metpy
from pyproj import Proj, transform
#from dask import compute
from dask.diagnostics import ProgressBar
from dask import compute
    
matplotlib.style.use('ggplot')

from himatpy.GRACE_MASCON.pygrace import (extract_grace, get_mascon_gdf, trend_analysis, get_cmwe_trend_analysis, select_mascons, aggregate_mascons)

import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/yingjung_cd/miniconda3/envs/himat/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/yingjung_cd/miniconda3/envs/himat/lib/python3.6/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %% [markdown]
# ### Open the LIS data

# %%
datadir = '/mnt/c/Users/HCD/UW_work/git/HiMAT/files/LIS/new/original_NASA/original_monthly/'

# %%
dgws = xr.open_mfdataset(datadir+'*.nc')*0.1

# %%
dgws_t=dgws

# %%
print(dgws)
# Out:
# <xarray.Dataset>
# Dimensions:           (SnowIce_profiles: 3, SnowLiq_profiles: 3, SnowTProf_profiles: 3, SoilMoist_profiles: 4, SoilTemp_profiles: 4, east_west: 137, north_south: 81, time: 5480, z_snow_profiles: 3, z_soil_profiles: 4)
# Coordinates:
#   * time              (time) datetime64[ns] 2003-02-01 2003-02-02 ... 2018-02-01
# Dimensions without coordinates: SnowIce_profiles, SnowLiq_profiles, SnowTProf_profiles, SoilMoist_profiles, SoilTemp_profiles, east_west, north_south, z_snow_profiles, z_soil_profiles
# Data variables:
#     lat               (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     lon               (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Swnet_tavg        (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Lwnet_tavg        (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qle_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qh_tavg           (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qg_tavg           (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Snowf_tavg        (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Rainf_tavg        (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Evap_tavg         (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qs_tavg           (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qsb_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qsm_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     VegT_tavg         (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     AvgSurfT_tavg     (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     RadT_tavg         (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Albedo_tavg       (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SWE_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowDepth_tavg    (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowIce_inst      (time, SnowIce_profiles, north_south, east_west) float32 dask.array<shape=(5480, 3, 81, 137), chunksize=(28, 3, 81, 137)>
#     SnowAge_tavg      (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SoilMoist_tavg    (time, SoilMoist_profiles, north_south, east_west) float32 dask.array<shape=(5480, 4, 81, 137), chunksize=(28, 4, 81, 137)>
#     SoilTemp_tavg     (time, SoilTemp_profiles, north_south, east_west) float32 dask.array<shape=(5480, 4, 81, 137), chunksize=(28, 4, 81, 137)>
#     ECanop_tavg       (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TVeg_tavg         (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ESoil_tavg        (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     CanopInt_tavg     (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SubSnow_tavg      (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TWS_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     GWS_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Snowcover_tavg    (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowTProf_inst    (time, SnowTProf_profiles, north_south, east_west) float32 dask.array<shape=(5480, 3, 81, 137), chunksize=(28, 3, 81, 137)>
#     Wind_f_tavg       (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Rainf_f_tavg      (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Tair_f_tavg       (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qair_f_tavg       (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Psurf_f_tavg      (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SWdown_f_tavg     (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     LWdown_f_tavg     (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     LAI_tavg          (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TotalPrecip_tavg  (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ActSnowNL_inst    (time, north_south, east_west) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     z_snow_inst       (time, z_snow_profiles, north_south, east_west) float32 dask.array<shape=(5480, 3, 81, 137), chunksize=(28, 3, 81, 137)>
#     z_soil_inst       (time, z_soil_profiles, north_south, east_west) float32 dask.array<shape=(5480, 4, 81, 137), chunksize=(28, 4, 81, 137)>
#     SnowLiq_inst      (time, SnowLiq_profiles, north_south, east_west) float32 dask.array<shape=(5480, 3, 81, 137), chunksize=(28, 3, 81, 137)>
# Attributes:
#     missing_value:           -9999.0
#     NUM_SOIL_LAYERS:         4
#     SOIL_LAYER_THICKNESSES:  [0.1 0.3 0.6 1. ]
#     title:                   LIS land surface model output
#     institution:             NASA GSFC
#     source:
#     history:                 created on date: 2018-12-07T18:48:14.415
#     references:              Kumar_etal_EMS_2006, Peters-Lidard_etal_ISSE_2007
#     conventions:             CF-1.6
#     comment:                 website: http://lis.gsfc.nasa.gov/
#     MAP_PROJECTION:          EQUIDISTANT CYLINDRICAL
#     SOUTH_WEST_CORNER_LAT:   20.875
#     SOUTH_WEST_CORNER_LON:   66.875
#     DX:                      0.25
#     DY:                      0.25

# %%
datadir2 = '/mnt/c/Users/HCD/UW_work/git/HiMAT/files/LIS/files/'

# %%
dgws1=xr.open_dataset(datadir2+'LISMonthly_new.nc')*0.1

# %% [markdown]
# ### Create a corrected lat, long format

# %%
lat=dgws1.latitude.drop('longitude')
lat=lat[:,-1]
lat=lat.rename({'north_south':'lat'})

# %%
long=dgws1.longitude.drop('latitude')
long=long[-1,:]
long=long.rename({'east_west':'long'})

# %% [markdown]
# ### Drop the extra coordinates and rename dimensions

# %%
#dgws=dgws.drop('latitude')

# %%
#dgws=dgws.drop('longitude')

# %%
#dgws = dgws.rename({'north_south':'lat','east_west':'long'})
#LIS = dgws.assign_coords(lat=lat,long=long, time=dgws.coords['time'])

# %%
#to_drop = [dim for dim in LIS.data_vars if LIS[dim].dims != ('time', 'lat', 'long')] 
#LIS = LIS.drop(to_drop)

# %%
#LIS=LIS.drop('latitude')

# %%
#LIS=LIS.drop('longitude')

# %%
#print(LIS)

# %% [markdown]
# ### Extract the lat, lon from data variables

# %%
#lat_coords=dgws_t.lat[-1,:,-1]
#lon_coords=dgws_t.lon[-1,-1,:]
#lon_coords[1] = lon_coords[0] + 0.775 # Filling in missing value
#lat_coords = lat_coords.rename({'north_south':'lat'})
#lon_coords = lon_coords.rename({'east_west':'long'})

# %%
dgws_t = dgws_t.drop(['lat', 'lon'])
dgws_t = dgws_t.rename({'north_south':'lat','east_west':'long'})
LIS_t = dgws_t.assign_coords(lat=lat,long=long, time=dgws_t.coords['time'])
# Drop arrays with dimension greater than 3
to_drop = [dim for dim in LIS_t.data_vars if LIS_t[dim].dims != ('time', 'lat', 'long')] 
LIS_t = LIS_t.drop(to_drop)

# %%
print(LIS_t)
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 81, long: 137, time: 5480)
# Coordinates:
#   * time              (time) datetime64[ns] 2003-02-01 2003-02-02 ... 2018-02-01
#     latitude          (lat) float64 ...
#     longitude         (long) float64 ...
#   * lat               (lat) float64 20.88 21.12 21.38 ... 40.38 40.62 40.88
#   * long              (long) float64 66.88 67.12 67.38 ... 100.4 100.6 100.9
# Data variables:
#     Swnet_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Lwnet_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qle_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qh_tavg           (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qg_tavg           (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Snowf_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Rainf_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Evap_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qs_tavg           (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qsb_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qsm_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     VegT_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     AvgSurfT_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     RadT_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Albedo_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SWE_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowDepth_tavg    (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowAge_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ECanop_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TVeg_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ESoil_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     CanopInt_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SubSnow_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TWS_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     GWS_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Snowcover_tavg    (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Wind_f_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Rainf_f_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Tair_f_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qair_f_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Psurf_f_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SWdown_f_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     LWdown_f_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     LAI_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TotalPrecip_tavg  (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ActSnowNL_inst    (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
# Attributes:
#     missing_value:           -9999.0
#     NUM_SOIL_LAYERS:         4
#     SOIL_LAYER_THICKNESSES:  [0.1 0.3 0.6 1. ]
#     title:                   LIS land surface model output
#     institution:             NASA GSFC
#     source:
#     history:                 created on date: 2018-12-07T18:48:14.415
#     references:              Kumar_etal_EMS_2006, Peters-Lidard_etal_ISSE_2007
#     conventions:             CF-1.6
#     comment:                 website: http://lis.gsfc.nasa.gov/
#     MAP_PROJECTION:          EQUIDISTANT CYLINDRICAL
#     SOUTH_WEST_CORNER_LAT:   20.875
#     SOUTH_WEST_CORNER_LON:   66.875
#     DX:                      0.25
#     DY:                      0.25

# %%
LIS=LIS_t.drop('latitude')

# %%
LIS=LIS.drop('longitude')

# %%
print(LIS)
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 81, long: 137, time: 5480)
# Coordinates:
#   * time              (time) datetime64[ns] 2003-02-01 2003-02-02 ... 2018-02-01
#   * lat               (lat) float64 20.88 21.12 21.38 ... 40.38 40.62 40.88
#   * long              (long) float64 66.88 67.12 67.38 ... 100.4 100.6 100.9
# Data variables:
#     Swnet_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Lwnet_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qle_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qh_tavg           (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qg_tavg           (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Snowf_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Rainf_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Evap_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qs_tavg           (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qsb_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qsm_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     VegT_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     AvgSurfT_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     RadT_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Albedo_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SWE_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowDepth_tavg    (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SnowAge_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ECanop_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TVeg_tavg         (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ESoil_tavg        (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     CanopInt_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SubSnow_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TWS_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     GWS_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Snowcover_tavg    (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Wind_f_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Rainf_f_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Tair_f_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Qair_f_tavg       (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     Psurf_f_tavg      (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     SWdown_f_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     LWdown_f_tavg     (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     LAI_tavg          (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     TotalPrecip_tavg  (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
#     ActSnowNL_inst    (time, lat, long) float32 dask.array<shape=(5480, 81, 137), chunksize=(28, 81, 137)>
# Attributes:
#     missing_value:           -9999.0
#     NUM_SOIL_LAYERS:         4
#     SOIL_LAYER_THICKNESSES:  [0.1 0.3 0.6 1. ]
#     title:                   LIS land surface model output
#     institution:             NASA GSFC
#     source:
#     history:                 created on date: 2018-12-07T18:48:14.415
#     references:              Kumar_etal_EMS_2006, Peters-Lidard_etal_ISSE_2007
#     conventions:             CF-1.6
#     comment:                 website: http://lis.gsfc.nasa.gov/
#     MAP_PROJECTION:          EQUIDISTANT CYLINDRICAL
#     SOUTH_WEST_CORNER_LAT:   20.875
#     SOUTH_WEST_CORNER_LON:   66.875
#     DX:                      0.25
#     DY:                      0.25

# %%
#LIS.to_netcdf('LISmonthly_rfok.nc')

# %% [markdown]
# ### Load well spatial domain and drop all the other data variable

# %%
LISr=LIS.sel(long=slice(65,100), lat=slice(21, 35))

# %%
LISr=LISr[['GWS_tavg']]

# %%
print(LISr)
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 56, long: 133, time: 5480)
# Coordinates:
#   * lat       (lat) float64 21.12 21.38 21.62 21.88 ... 34.12 34.38 34.62 34.88
#   * long      (long) float64 66.88 67.12 67.38 67.62 ... 99.12 99.38 99.62 99.88
#   * time      (time) datetime64[ns] 2003-02-01 2003-02-02 ... 2018-02-01
# Data variables:
#     GWS_tavg  (time, lat, long) float32 dask.array<shape=(5480, 56, 133), chunksize=(28, 56, 133)>
# Attributes:
#     missing_value:           -9999.0
#     NUM_SOIL_LAYERS:         4
#     SOIL_LAYER_THICKNESSES:  [0.1 0.3 0.6 1. ]
#     title:                   LIS land surface model output
#     institution:             NASA GSFC
#     source:
#     history:                 created on date: 2018-12-07T18:48:14.415
#     references:              Kumar_etal_EMS_2006, Peters-Lidard_etal_ISSE_2007
#     conventions:             CF-1.6
#     comment:                 website: http://lis.gsfc.nasa.gov/
#     MAP_PROJECTION:          EQUIDISTANT CYLINDRICAL
#     SOUTH_WEST_CORNER_LAT:   20.875
#     SOUTH_WEST_CORNER_LON:   66.875
#     DX:                      0.25
#     DY:                      0.25

# %%
# Calculate monthly average
LISr=LISr.resample(time='1m').mean(dim='time')

# %%
print(LISr)

# %% [markdown]
# ### LIS gws anomaly

# %%
LGWS_mean = LISr.groupby('time.month').mean('time')
LISa = LISr.groupby('time.month') - LGWS_mean

# %%
print(LISa)

# %%
fp="/mnt/c/Users/HCD/UW_work/git/HiMAT/files/WBM/Watershed_boundaries/dugwells_districts_d.shp"

# %%
well_d=gpd.read_file(fp)
shdf = salem.read_shapefile(fp)

# %% [markdown]
# ### Download the GRACE data from S3 bucket

# %%
fileName = '../../files/GRACE/GSFC.glb.200301_201607_v02.4-ICE6G.h5'
grace_file = os.path.abspath(fileName)
f = extract_grace(grace_file)
# Out:
# Data extracted:
# ---
# Group: mascon
# ---
# <HDF5 dataset "area_deg": shape (1, 41168), type "<f8">
# <HDF5 dataset "area_km2": shape (1, 41168), type "<f8">
# <HDF5 dataset "basin": shape (1, 41168), type "<f8">
# <HDF5 dataset "elev_flag": shape (1, 41168), type "<f8">
# <HDF5 dataset "lat_center": shape (1, 41168), type "<f8">
# <HDF5 dataset "lat_span": shape (1, 41168), type "<f8">
# <HDF5 dataset "location": shape (1, 41168), type "<f8">
# <HDF5 dataset "lon_center": shape (1, 41168), type "<f8">
# <HDF5 dataset "lon_span": shape (1, 41168), type "<f8">
# ---
# Group: size
# ---
# <HDF5 dataset "N_arcs": shape (1, 1), type "<f8">
# <HDF5 dataset "N_mascon_times": shape (1, 1), type "<f8">
# <HDF5 dataset "N_mascons": shape (1, 1), type "<f8">
# ---
# Group: solution
# ---
# <HDF5 dataset "cmwe": shape (41168, 148), type "<f8">
# ---
# Group: time
# ---
# <HDF5 dataset "list_ref_days_solution": shape (1, 4128), type "<f8">
# <HDF5 dataset "n_ref_days_solution": shape (1, 148), type "<f8">
# <HDF5 dataset "n_ref_days_window": shape (1, 148), type "<f8">
# <HDF5 dataset "ref_days_first": shape (1, 148), type "<f8">
# <HDF5 dataset "ref_days_last": shape (1, 148), type "<f8">
# <HDF5 dataset "ref_days_middle": shape (1, 148), type "<f8">
# <HDF5 dataset "yyyy_doy_yrplot_middle": shape (3, 148), type "<f8">
# ---
# Group: uncertainty
# ---
# <HDF5 dataset "leakage_2sigma": shape (41168, 148), type "<f8">
# <HDF5 dataset "leakage_trend": shape (41168, 148), type "<f8">
# <HDF5 dataset "noise_2sigma": shape (41168, 148), type "<f8">

# %%
mascon = f['mascon']
soln = f['solution']
time = f['time']

mascon_gdf = get_mascon_gdf(mascon)
## we need to track mascon numbers later, which we get from the index, so make a new "mascon" column
mascon_gdf['mascon'] = mascon_gdf.index
# Out:
# There are 41168 Mascons in this dataset.

# %% [markdown]
# ### Clip the GRACE mascons to the domain of GWA

# %%
masked_gdf4 = select_mascons(LISa, mascon_gdf)

# %%
#print(masked_gdf4)

# %% [markdown]
# ### The main processing step that calculates a mean value across each mascon

# %%
agg_data = aggregate_mascons(LISa, masked_gdf4)

# %% [markdown]
# ### Convert LIS array to Pandas dataframe for plotting

# %%
A3 = agg_data['data']

names = ['products', 'mascons', 'time']
index = pd.MultiIndex.from_product([agg_data[n] for n in names], names=names)
df4 = pd.DataFrame({'A3': A3.flatten()}, index=index)['A3']
df4 = df4.unstack(level='products').swaplevel().sort_index()
df4.columns = agg_data['products']
df4.index.names = ['date','mascon']

# %% [markdown]
# ### Drop the NA values in the new GWSA mascons dataframe

# %%
dfok4=df4.dropna(how='any')

# %%
#print(dfok4)

# %% [markdown]
# ### Convert GRACE time series to Pandas dataframe

# %%
t = pd.DataFrame(data = {
    'time': f['time']["ref_days_middle"][0,:]
})

grc_lst = []
for m in agg_data['mascons']:
    df = pd.DataFrame(data={
        'cmwe': soln['cmwe'][m][:],
        'mascon': m
    })
    df.index = t['time'].apply(lambda x: datetime(2001,12,31) + timedelta(days=x))
    grc_lst.append(df)
    
gracedf = pd.concat(grc_lst)

# %%
print(gracedf)

# %% [markdown]
# ## Calculate mean LIS values by time

# %%
grct = gracedf.groupby('time').mean()
lisst = dfok4.groupby('date').mean()

# %%
gok=grct - grct.iloc[0].cmwe
gok1 = grct.reset_index()
gok1['time']=pd.to_datetime(gok1['time']).dt.floor('d')

# %%
A=lisst - lisst.iloc[0].GWS_tavg 
#A.to_csv('wbm_data.csv')
Aok = lisst.reset_index()
#print(Aok)
Aok['date']=pd.to_datetime(Aok['date'])

# %%
#Aok['GWS_tavg']=Aok['GWS_tavg']*10

# %% [markdown]
# ### Plot GWSA trend from LIS time series

# %%
fig, ax = plt.subplots(1, figsize=(10, 8))
gok1.plot(ax=ax, y='cmwe', x='time',linewidth = 2,color='brown')
Aok.plot(ax=ax,y='GWS_tavg', x='date', linewidth = 2,color='blue') #x='date'
plt.ylabel('ground water storage anomaly(cm)', fontsize = 14)
plt.xlabel('year', fontsize = 14) #'year'
plt.xticks(rotation=0)
ax.legend(['GRACE','LIS'],fontsize = 14, loc = 1)
font = {'family' : 'Times',
        'size'   : 14}
matplotlib.rc('font', **font)

# %%
GRACE_mass = gok1.cmwe.values
GRACE_decyear = f['time']['yyyy_doy_yrplot_middle'][2, :]
LIS = Aok.GWS_tavg.values
LIS_dy1 = pd.Series(Aok.date).apply(lambda x: pyasl.decimalYear(x))

# %%
plt.figure(figsize=(10,8))
plt.plot(GRACE_decyear,signal.detrend(GRACE_mass, type = 'linear'),color='brown',linewidth = 2)
plt.plot(LIS_dy1,signal.detrend(LIS, type = 'linear'),color='blue',linewidth = 2)

plt.ylabel('ground water storage anomaly (cm)', fontsize = 14)
plt.xlabel('year', fontsize = 14)
plt.legend(['GRACE','LIS'],fontsize = 14, loc = 1)

font = {'family' : 'Times',
        'size'   : 14}

matplotlib.rc('font', **font)

# %%
t_grace=get_cmwe_trend_analysis(masked_gdf4, f)

# %%
t_grace_cl =gpd.overlay(shdf,t_grace, how='intersection')

# %%
#print(t_grace_cl)

# %%
plt.figure(figsize=(12,8))
t_grace_cl.plot(column='avg_mass_change_cm',cmap='viridis', legend=True)
plt.ylabel('latitude', fontsize = 12)
plt.xlabel('longtitude', fontsize = 12)
# Out:
# Text(0.5, 55.92319665921714, 'longtitude')

# %% [markdown]
# ### Calculate LIS GWSA trend

# %% [markdown]
# #### Convert the date from multiindex into date column

# %%
LISga = dfok4.reset_index()

# %%
#print(LISga)

# %% [markdown]
# ### Calculate LIS GWSA trend per mascon

# %%
LIS_t=pd.DataFrame()
LIS_t['trend']=LISga.groupby('mascon').apply(lambda x: trend_analysis(x['date'].apply(lambda x: pyasl.decimalYear(x)), 
                                                   x['GWS_tavg'], optimization = True)[1] )

# %%
#LIS_t['trend']=LIS_t['trend']*10

# %% [markdown]
# ### Join the GWSA trend with mascon dataframe (get geometry)

# %%
mascon_t_g=t_grace_cl.join(LIS_t, on='mascon')

# %% [markdown]
# ### Plot the spatial trend of each mascon for UGWA data

# %%
# WBM trend for indus basin
mascon_t_g.plot(column='trend',cmap='viridis', legend=True)

# %%
mascon_t_g.plot(column='trend',cmap='viridis',vmin=-0.5,vmax=1, legend=True)
